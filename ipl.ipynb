# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("matches.csv")
df
df=df[df['season']==2017]   #to only show show ipl season 2017 records.df
df
# Out:
#     id  season        city        date                        team1  \
# 0    1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2    2017        Pune  2017-04-06               Mumbai Indians
# 2    3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 7    8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 8    9    2017        Pune  2017-04-11             Delhi Daredevils
# 9   10    2017      Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# ...

# %% [markdown]
# # no. of matches played in 2017 ipl edition.

# %%
no_of_matches=df.shape[0]
print(no_of_matches)
# Out:
# 59

# %% [markdown]
# # what percentages of match are won by the toss winners.?

# %%
#what is the relation of the toss_winner with the winner.
p=df[df['winner']==df['toss_winner']]
#now p is the dataframe in which the toss_winners are eventually the winners.
#chances that a toss_winner is a winner is:
q=(p.shape[0]/df.shape[0])*100
q
# Out:
# 0

# %% [markdown]
# # who won the final match?

# %%
last_match=df.tail(1)
last_match['winner']    #it was Mumbai Indians who won the last match
# Out:
# 58    Mumbai Indians
# Name: winner, dtype: object

# %% [markdown]
# # which two teams reached the finals?

# %%
last_match[['team1','team2']]   #we need to pass a list
# Out:
#              team1                   team2
# 58  Mumbai Indians  Rising Pune Supergiant

# %%
#it was Rising Pune Supergiants and Mumbai Indians who reached the finals.

# %% [markdown]
# # In how many matches Duckworth Lewis was used.

# %%
#answer is 1

# %% [markdown]
# # what percenatge of matches are won after fielding first?

# %%
df=df[['toss_winner','toss_decision','winner']]

# %%
equal=df[df['toss_winner']==df['winner']]  #dataframe of the team who have won the match after winning toss.

# %%
o=equal[df.toss_decision=='field']    #this will show the dataframe of the team who have won fielding first.
o.shape[0]
# Out:
# /home/shivam/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 28

# %%
#28 is the number of matches won fielding first
games_won_field_first=(28/59)*100

# %%
games_won_field_first
# Out:
# 0

# %%
#47.45762711864407 is the percenaage of matches won, fielding first.
